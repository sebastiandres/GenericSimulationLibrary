# %%
from GenericSimulationLibrary import SimulationInterface

inputs = {
         "x_min":0,
         "x_max":10,
         "N_points":30,
         "m":2,
         "b":10,
         "filename":"test_1.sim",
        }
data = {
         "x":[ 1.1,  3.1,  5.9,  8.7], 
         "y":[10.5, 17.3, 21.1, 30.5], 
         "plot_options":None
       }

SI = SimulationInterface()

# %%
SI.status()
# Out:
# System configuration:
#     environment: python
#     python version: 3.7.4
#     GenericSimulationLibrary version: 0.0.3
#     numpy version: 1.17.2
#     matplotlib version: 3.0.3
# Inputs:
#     No inputs
# Data:
#     No data

# %%
SI.new(inputs, data)

# %%
SI.status()
# Out:
# System configuration:
#     environment: python
#     python version: 3.7.4
#     GenericSimulationLibrary version: 0.0.3
#     numpy version: 1.17.2
#     matplotlib version: 3.0.3
# Inputs:
#     x_min 0
#     x_max 10
#     N_points 30
#     m 2
#     b 10
#     filename test_1.sim
# Data:
#     x [1.1, 3.1, 5.9, 8.7]
#     y [10.5, 17.3, 21.1, 30.5]
#     plot_options None

# %%
SI.plot(display=True)

# %%
SI.simulate()
# Out:
# Elapsed time: 012 seconds

# %%
SI.plot(display=True)

# %%
SI.save()
# Out:
# Saving simulation into file  test_1.sim

# %%
SI.export_xlsx("test_1.xlsx")
# Out:
# Exported simulation as xlsx into file test_1.xlsx
